# %%
from ohmysportsfeedspy import MySportsFeeds
import json
import pprint

# %%
Data_query = MySportsFeeds('1.2', verbose=True)
Data_query.authenticate('7af68037-2f3f-4bf5-bbd5-173ad2', 'Dk30RQHT')
Output = Data_query.msf_get_data(league='nfl', season='upcoming', feed='player_injuries', format='json')
# Out:
# Making API request to 'https://api.mysportsfeeds.com/v1.2/pull/nfl/upcoming/player_injuries.json'.
#   with headers:
# {'Accept-Encoding': 'gzip', 'User-Agent': 'MySportsFeeds Python/1.0.0 (Linux-4.4.0-1061-aws-x86_64-with-debian-9.5)', 'Authorization': 'Basic N2FmNjgwMzctMmYzZi00YmY1LWJiZDUtMTczYWQyOkRrMzBSUUhU'}
#  and params:
# {'force': 'false'}
# Data hasn't changed since last call

# %%
'11"'[:-1]
# Out:
# '11'

# %%
total_weight = 0
total_height = 0
for item in Output['playerinjuries']['playerentry']:
    name = item["player"]["FirstName"] + ' ' + item["player"]["LastName"]
    weight = item["player"]["Weight"]
    height = item["player"]["Height"]
    ft, inch = height.split("'")
    
    injury = item["injury"]
    total_weight = total_weight + int(weight)
    ft_inch = int(ft)*12 + int(inch[:-1])
    total_height = total_height + ft_inch
    print(name, height, weight, injury)
avg_height = total_height/15
avg_height = avg_height/12
inch_height = avg_height-int(avg_height)
inch_height = inch_height*10
print("The average weight for an injured nfl player is:", total_weight/15, "lbs")
#inch_height = (avg_height - int(avg_height))*12
print("The average height for an injured nfl player is:", int(avg_height), "ft", round(inch_height), "inch")
# Out:
# Alan Branch 6'6" 350 knee (Questionable)
# Malcom Brown 6'2" 320 foot (Questionable)
# Malcolm Butler 5'11" 190 flu (Probable)
# Fletcher Cox 6'4" 300 calf (Probable)
# Ronald Darby 5'11" 193 illness (Probable)
# Nate Ebner 6'0" 220 knee (Questionable)
# Dannell Ellerbe 6'1" 245 hamstring (Questionable)
# Timmy Jernigan 6'2" 302 illness (Probable)
# Jonathan Jones 5'10" 190 foot (Questionable)
# Sidney Jones 6'0" 181 hamstring (Questionable)
# Brandon King 6'2" 220 knee (Probable)
# Devin McCourty 5'10" 195 shoulder (Probable)
# LaAdrian Waddle 6'6" 328 knee (Questionable)
# Joe Walker 6'2" 236 neck (Questionable)
# Deatrich Wise 6'5" 271 concussion (Probable)
# The average weight for an injured nfl player is: 249.4 lbs
# The average height for an injured nfl player is: 6 ft 1 inch

# %%
Output
# Out:
# {'playerinjuries': {'lastUpdatedOn': '2018-08-06 6:57:29 PM',
#   'playerentry': [{'player': {'ID': '7602',
#      'LastName': 'Branch',
#      'FirstName': 'Alan',
#      'JerseyNumber': '97',
#      'Position': 'NT',
#      'Height': '6\'6"',
#      'Weight': '350',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'knee (Questionable)'},
#    {'player': {'ID': '7599',
#      'LastName': 'Brown',
#      'FirstName': 'Malcom',
#      'JerseyNumber': '90',
#      'Position': 'DT',
#      'Height': '6\'2"',
#      'Weight': '320',
#      'BirthDate': '1994-02-02',
#      'Age': '24',
#      'BirthCity': 'Brenham, TX',
#      'BirthCountry': 'USA',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'foot (Questionable)'},
#    {'player': {'ID': '7622',
#      'LastName': 'Butler',
#      'FirstName': 'Malcolm',
#      'JerseyNumber': '21',
#      'Position': 'CB',
#      'Height': '5\'11"',
#      'Weight': '190',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'flu (Probable)'},
#    {'player': {'ID': '8052',
#      'LastName': 'Cox',
#      'FirstName': 'Fletcher',
#      'JerseyNumber': '91',
#      'Position': 'DE',
#      'Height': '6\'4"',
#      'Weight': '300',
#      'IsRookie': 'false'},
#     'team': {'ID': '54',
#      'City': 'Philadelphia',
#      'Name': 'Eagles',
#      'Abbreviation': 'PHI'},
#     'injury': 'calf (Probable)'},
#    {'player': {'ID': '6275',
#      'LastName': 'Darby',
#      'FirstName': 'Ronald',
#      'JerseyNumber': '28',
#      'Position': 'CB',
#      'Height': '5\'11"',
#      'Weight': '193',
#      'BirthDate': '1994-01-02',
#      'Age': '24',
#      'BirthCity': 'Oxon Hill, MD',
#      'BirthCountry': 'USA',
#      'IsRookie': 'false'},
#     'team': {'ID': '54',
#      'City': 'Philadelphia',
#      'Name': 'Eagles',
#      'Abbreviation': 'PHI'},
#     'injury': 'illness (Probable)'},
#    {'player': {'ID': '7629',
#      'LastName': 'Ebner',
#      'FirstName': 'Nate',
#      'JerseyNumber': '43',
#      'Position': 'DB',
#      'Height': '6\'0"',
#      'Weight': '220',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'knee (Questionable)'},
#    {'player': {'ID': '7705',
#      'LastName': 'Ellerbe',
#      'FirstName': 'Dannell',
#      'JerseyNumber': '59',
#      'Position': 'OLB',
#      'Height': '6\'1"',
#      'Weight': '245',
#      'BirthDate': '1985-11-29',
#      'Age': '32',
#      'BirthCity': 'Hamlet, NC',
#      'BirthCountry': 'USA',
#      'IsRookie': 'false'},
#     'team': {'ID': '54',
#      'City': 'Philadelphia',
#      'Name': 'Eagles',
#      'Abbreviation': 'PHI'},
#     'injury': 'hamstring (Questionable)'},
#    {'player': {'ID': '6166',
#      'LastName': 'Jernigan',
#      'FirstName': 'Timmy',
#      'JerseyNumber': '97',
#      'Position': 'DT',
#      'Height': '6\'2"',
#      'Weight': '302',
#      'IsRookie': 'false'},
#     'team': {'ID': '54',
#      'City': 'Philadelphia',
#      'Name': 'Eagles',
#      'Abbreviation': 'PHI'},
#     'injury': 'illness (Probable)'},
#    {'player': {'ID': '9940',
#      'LastName': 'Jones',
#      'FirstName': 'Jonathan',
#      'JerseyNumber': '31',
#      'Position': 'CB',
#      'Height': '5\'10"',
#      'Weight': '190',
#      'BirthDate': '1993-09-20',
#      'Age': '24',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'foot (Questionable)'},
#    {'player': {'ID': '13283',
#      'LastName': 'Jones',
#      'FirstName': 'Sidney',
#      'JerseyNumber': '22',
#      'Position': 'CB',
#      'Height': '6\'0"',
#      'Weight': '181',
#      'BirthDate': '1996-05-21',
#      'Age': '22',
#      'BirthCity': 'Diamond Bar, CA',
#      'BirthCountry': 'USA',
#      'IsRookie': 'false'},
#     'team': {'ID': '54',
#      'City': 'Philadelphia',
#      'Name': 'Eagles',
#      'Abbreviation': 'PHI'},
#     'injury': 'hamstring (Questionable)'},
#    {'player': {'ID': '7632',
#      'LastName': 'King',
#      'FirstName': 'Brandon',
#      'JerseyNumber': '36',
#      'Position': 'DB',
#      'Height': '6\'2"',
#      'Weight': '220',
#      'BirthDate': '1993-06-08',
#      'Age': '25',
#      'BirthCity': 'Alabaster, AL',
#      'BirthCountry': 'USA',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'knee (Probable)'},
#    {'player': {'ID': '7633',
#      'LastName': 'McCourty',
#      'FirstName': 'Devin',
#      'JerseyNumber': '32',
#      'Position': 'DB',
#      'Height': '5\'10"',
#      'Weight': '195',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'shoulder (Probable)'},
#    {'player': {'ID': '6862',
#      'LastName': 'Waddle',
#      'FirstName': 'LaAdrian',
#      'JerseyNumber': '68',
#      'Position': 'OT',
#      'Height': '6\'6"',
#      'Weight': '328',
#      'BirthDate': '1991-07-21',
#      'Age': '27',
#      'BirthCity': 'College Station, TX',
#      'BirthCountry': 'USA',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'knee (Questionable)'},
#    {'player': {'ID': '9711',
#      'LastName': 'Walker',
#      'FirstName': 'Joe',
#      'JerseyNumber': '59',
#      'Position': 'ILB',
#      'Height': '6\'2"',
#      'Weight': '236',
#      'BirthDate': '1992-12-11',
#      'Age': '25',
#      'IsRookie': 'false'},
#     'team': {'ID': '54',
#      'City': 'Philadelphia',
#      'Name': 'Eagles',
#      'Abbreviation': 'PHI'},
#     'injury': 'neck (Questionable)'},
#    {'player': {'ID': '13084',
#      'LastName': 'Wise',
#      'FirstName': 'Deatrich',
#      'JerseyNumber': '91',
#      'Position': 'DE',
#      'Height': '6\'5"',
#      'Weight': '271',
#      'BirthDate': '1994-07-26',
#      'Age': '24',
#      'IsRookie': 'false'},
#     'team': {'ID': '50',
#      'City': 'New England',
#      'Name': 'Patriots',
#      'Abbreviation': 'NE'},
#     'injury': 'concussion (Probable)'}]}}

# %%
item["player"]["Weight"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-0571aefc59b1> in <module>()
# ----> 1 item["player"]["Weight"]
#
# TypeError: string indices must be integers
